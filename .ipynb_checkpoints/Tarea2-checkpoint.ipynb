# %% [markdown]
# # Tarea 2

# %% [markdown]
# GitHub: https://github.com/romloayza/econometria_tarea1

# %% [markdown]
# Integrantes:
# - Romina Loayza
# - Nicolás Gutierrez
# - Alfredo Aro

# %%
import pandas as pd
import os
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm # Import Statsmodels for statistical modeling
from sklearn.linear_model import LinearRegression # Import LinearRegression from scikit-learn for regression analysis
from sklearn.metrics import mean_squared_error, r2_score # Import metrics for model evaluation
from statsmodels.stats.diagnostic import het_breuschpagan, het_white # Import tests for heteroscedasticity
from scipy import stats
from tabulate import tabulate
from sklearn.metrics import mean_squared_error, r2_score
from statsmodels.stats.diagnostic import het_breuschpagan, het_white
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# ## 1. Limpieza de la data

# %% [markdown]
# ### Módulo Empleo

# %%
csv_path = os.path.join("data", "ENPOVE2022_V_600 Empleo.csv")
m_empleo= pd.read_csv(csv_path,encoding = "latin-1", low_memory=False)
m_empleo.columns= m_empleo.columns.str.lower()
m_empleo
# Out:
#        ï»¿ccdd departamento  ccpp provincia  ccdi  distrito    ciudad  \
# 0            2       ANCASH    18     SANTA     1  CHIMBOTE  Chimbote
# 1            2       ANCASH    18     SANTA     1  CHIMBOTE  Chimbote
# 2            2       ANCASH    18     SANTA     1  CHIMBOTE  Chimbote
# 3            2       ANCASH    18     SANTA     1  CHIMBOTE  Chimbote
# 4            2       ANCASH    18     SANTA     1  CHIMBOTE  Chimbote
# ...        ...          ...   ...       ...   ...       ...       ...
# 11616       24       TUMBES     1    TUMBES     1    TUMBES    Tumbes
# 11617       24       TUMBES     1    TUMBES     1    TUMBES    Tumbes
# 11618       24       TUMBES     1    TUMBES     1    TUMBES    Tumbes
# 11619       24       TUMBES     1    TUMBES     1    TUMBES    Tumbes
# 11620       24       TUMBES     1    TUMBES     1    TUMBES    Tumbes
#
#        conglomerado  nselv  vivienda  ...  gedad1  gedad2  p625_d  p625_p  \
# 0           1206802   9340         3  ...       2       2       1       1
# 1           1206802   9340         3  ...       0       0
# 2           1206802   9340         3  ...       3       3       1       1
# 3           1207001   9345         6  ...       2       2       1       1
# 4           1207001   9345         6  ...       0       0
# ...             ...    ...       ...  ...     ...     ...     ...     ...
# 11616         44789    393        12  ...       2       2       1       1
# 11617         44789    393        12  ...       1       1       1       1
# 11618         44789    396        13  ...       3       3       1       1
# 11619         44789    396        13  ...       3       4
# 11620         44789    397        14  ...       2       2       1       1
#
#        m622_1  m622_2  ingtot  ingtot_monetario ingtot_no_monetario  \
# 0        1600     300    1900              1600                 300
# 1
# 2                        1200              1200                   0
# 3         800     300    1100               800                 300
# 4
# ...       ...     ...     ...               ...                 ...
# 11616                    1300              1300                   0
# 11617                    1299              1299                   0
# 11618                     312               312                   0
# 11619
# 11620    1500     300    1800              1500                 300
#
#       factorfinal
# 0       13.175820
# 1       13.175820
# 2       13.175820
# 3       26.351641
# 4       26.351641
# ...           ...
# 11616   18.422158
# 11617   18.422158
# 11618   12.281439
# 11619   12.281439
# 11620   12.281439
#
# [11621 rows x 156 columns]

# %% [markdown]
# ### Módulo Residentes del Hogar

# %%
csv_path = os.path.join("data", "ENPOVE2022_V_200_Residentes.csv")
m_residentes= pd.read_csv(csv_path,encoding = "latin-1", low_memory=False)
m_residentes.columns= m_residentes.columns.str.lower()
m_residentes
# Out:
#        ï»¿ccdd departamento  ccpp provincia  ccdi       distrito    ciudad  \
# 0           15         LIMA     1      LIMA    19          LURIN      Lima
# 1           15         LIMA     1      LIMA    19          LURIN      Lima
# 2            7         LIMA     1    CALLAO     1         CALLAO      Lima
# 3           14   LAMBAYEQUE     1  CHICLAYO     6    LA VICTORIA  Chiclayo
# 4            2       ANCASH    18     SANTA     1       CHIMBOTE  Chimbote
# ...        ...          ...   ...       ...   ...            ...       ...
# 12482        4     AREQUIPA     1  AREQUIPA     7  JACOBO HUNTER  Arequipa
# 12483        4     AREQUIPA     1  AREQUIPA     7  JACOBO HUNTER  Arequipa
# 12484        4     AREQUIPA     1  AREQUIPA     7  JACOBO HUNTER  Arequipa
# 12485        4     AREQUIPA     1  AREQUIPA     7  JACOBO HUNTER  Arequipa
# 12486        4     AREQUIPA     1  AREQUIPA     7  JACOBO HUNTER  Arequipa
#
#        conglomerado  nselv  vivienda  ...  p211_n  p211_1 p200_aportante  \
# 0             29806  68378        12  ...       2  4.Otro
# 1             29778  68073         9  ...       1  4.Otro
# 2           1814802  16137         9  ...       1  4.Otro
# 3              3976   4564         9  ...       1  4.Otro
# 4             12284  10250         9  ...       5  4.Otro
# ...             ...    ...       ...  ...     ...     ...            ...
# 12482         43374  14722        29  ...
# 12483         43377  14725        32  ...
# 12484         43377  14725        32  ...
# 12485         43410  14694         7  ...
# 12486         43410  14694         7  ...
#
#       p211_n_parentesco p211_n_sexo p211_n_aãos  p211_n_meses  p211_n_ecivil  \
# 0                     2           2           29                            1
# 1                     1           2           35                            1
# 2                     1           2           35                            6
# 3                     1           2           17                            6
# 4                    11           2           17                            1
# ...                 ...         ...          ...           ...            ...
# 12482
# 12483
# 12484
# 12485
# 12486
#
#        p211_n_migrante factorfinal
# 0                    1  133.030686
# 1                    1  133.030686
# 2                    1  133.030686
# 3                    1   18.043333
# 4                    1   26.351641
# ...                ...         ...
# 12482                    66.313829
# 12483                   132.627658
# 12484                   132.627658
# 12485                   132.627658
# 12486                   132.627658
#
# [12487 rows x 42 columns]

# %% [markdown]
# ### Merge

# %%
columnas_comunes = ['ï»¿ccdd', 'ccpp', 'ccdi', 'conglomerado', 'nselv', 'vivienda', 'thogar', 'nhogar', 'p200_n']
#estas son las columnas comunes entra las dos bases de datos que nos ayudarán a realizar el merge

# %%
print("Contenido de las columnas comunes en m_residentes:")
print(m_residentes[columnas_comunes].head())

print("\nContenido de las columnas comunes en m_empleo:")
print(m_empleo[columnas_comunes].head())
# Out:
# Contenido de las columnas comunes en m_residentes:
#    ï»¿ccdd  ccpp  ccdi  conglomerado  nselv  vivienda  thogar  nhogar  p200_n
# 0       15     1    19         29806  68378        12       1       1       5
# 1       15     1    19         29778  68073         9       1       1       6
# 2        7     1     1       1814802  16137         9       1       1       5
# 3       14     1     6          3976   4564         9       1       1       1
# 4        2    18     1         12284  10250         9       1       1       5
#
# Contenido de las columnas comunes en m_empleo:
#    ï»¿ccdd  ccpp  ccdi  conglomerado  nselv  vivienda  thogar  nhogar  p200_n
# 0        2    18     1       1206802   9340         3       1       1       1
# 1        2    18     1       1206802   9340         3       1       1       4
# 2        2    18     1       1206802   9340         3       1       1       5
# 3        2    18     1       1207001   9345         6       1       1       1
# 4        2    18     1       1207001   9345         6       1       1       2

# %% [markdown]
# ### Creación de código único

# %%
m_residentes['codigo_unico'] = m_residentes[columnas_comunes].astype(str).agg('-'.join, axis=1)
m_empleo['codigo_unico'] = m_empleo[columnas_comunes].astype(str).agg('-'.join, axis=1)

# %%
for columna in columnas_comunes:
    m_residentes[columna] = m_residentes[columna].astype(str).str.strip()  
    m_empleo[columna] = m_empleo[columna].astype(str).str.strip()

# %%
coincidencias = m_residentes['codigo_unico'].isin(m_empleo['codigo_unico'])
coincidencias
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 12482    True
# 12483    True
# 12484    True
# 12485    True
# 12486    True
# Name: codigo_unico, Length: 12487, dtype: bool

# %%
venezolanos = pd.merge(m_residentes, m_empleo, on='codigo_unico', how='inner', suffixes=('_residente', '_empleo'))

# %%
columnas_residente = set(venezolanos.filter(regex='_residente').columns)
columnas_empleo = set(venezolanos.filter(regex='_empleo').columns)

# %%
for col_residente in columnas_residente:
    # Identificar el nombre base de la columna
    col_base = col_residente.replace('_residente', '')
    col_empleo = col_base + '_empleo'
    
    if col_empleo in columnas_empleo:
        # Priorizar la columna de m_empleo
        venezolanos[col_base] = venezolanos[col_empleo]
        # Eliminar las columnas duplicadas
        venezolanos.drop([col_residente, col_empleo], axis=1, inplace=True)

# %% [markdown]
# ### **Selección de variables**
# - p203: ¿Cuál es la relación de parentesco con el/la jefa del hogar? **[Categórica]**
# - p204: Sexo **[Categórica]**
# - p205_a: ¿Qué edad tiene en años cumplidos? **[Numérica]**
# - p208: ¿Migró de Venezuela? **[Categórica]** - esta variable es más que todo para asegurar que todos hayan dicho que 'sí'
# - p613: Usted, ¿ha firmado algún contrato laboral o brindó algún comprobante de pago por sus servicios? **[Categórica]**
# - p616a: Normalmente, ¿Cuántas horas trabaja a la semana en todas sus ocupaciones? **[Numérica]**
# - p621: En su ocupación principal, ¿la frecuencia con que a usted le pagan es...? **[Categórica]**
# - p622_1: ¿Cuánto fue su ingreso total sin descuento en el/la anterior, incluyendo horas extra? **[Numérica]**
# - estrato: Estrato social **[Categórica]**
# - p636: En Venezuela, ¿tenía usted trabajo antes de iniciar su viaje? **[Categórica]**

# %%
variables =['p203','p204', 'p205_a', 'p208', 'p613', 'p621', 'p622_1', 'p636', 'estrato', 'p616a']
venezolanos = venezolanos[variables].copy()
venezolanos.head()
# Out:
#                   p203     p204 p205_a   p208 p613 p621 p622_1 p636  estrato  \
# 0      8.Otro pariente  2.Mujer     16  1.SÃ­                     2        4
# 1        4.Yerno/nuera  2.Mujer     17  1.SÃ­                     2        4
# 2        4.Yerno/nuera  2.Mujer     17  1.SÃ­                     2        3
# 3   1.Jefe/a del hogar  2.Mujer     17  1.SÃ­    2    1     30    2        4
# 4  11.Otro no pariente  2.Mujer     17  1.SÃ­                     2        4
#
#   p616a
# 0
# 1
# 2
# 3
# 4

# %%
import warnings
warnings.filterwarnings('ignore')
venezolanos = venezolanos.applymap(lambda x: ''.join(filter(str.isdigit, str(x))))
venezolanos
# Out:
#       p203 p204 p205_a p208 p613 p621 p622_1 p636 estrato p616a
# 0        8    2     16    1                     2       4
# 1        4    2     17    1                     2       4
# 2        4    2     17    1                     2       3
# 3        1    2     17    1    2    1     30    2       4
# 4       11    2     17    1                     2       4
# ...    ...  ...    ...  ...  ...  ...    ...  ...     ...   ...
# 11616    2    2     31    1    2    4    830    2       3
# 11617    1    1     30    1    1    2    800    1       4
# 11618    2    2     25    1    1    2    300    2       4
# 11619    1    1     48    1    2    4    270    1       2
# 11620    3    1     17    1                     2       2
#
# [11621 rows x 10 columns]

# %% [markdown]
# ### Revisamos el tipo de datos

# %%
venezolanos.dtypes
# Out:
# p203       object
# p204       object
# p205_a     object
# p208       object
# p613       object
# p621       object
# p622_1     object
# p636       object
# estrato    object
# p616a      object
# dtype: object

# %%
venezolanos = venezolanos.apply(pd.to_numeric, errors="coerce") 
venezolanos.dropna(inplace=True) 
venezolanos
# Out:
#        p203  p204  p205_a  p208  p613  p621  p622_1  p636  estrato  p616a
# 14        4     2    17.0     1   2.0   1.0    20.0   1.0        3    8.0
# 45        1     1    52.0     1   2.0   1.0    80.0   1.0        2   50.0
# 65        1     2    36.0     1   2.0   2.0   350.0   1.0        3   66.0
# 82        1     1    48.0     1   2.0   4.0  1000.0   1.0        4   72.0
# 111      11     1    26.0     1   2.0   2.0   280.0   1.0        3   48.0
# ...     ...   ...     ...   ...   ...   ...     ...   ...      ...    ...
# 11530     3     2    23.0     1   2.0   4.0  1800.0   1.0        4   48.0
# 11531     8     1    26.0     1   2.0   2.0   330.0   1.0        4   66.0
# 11545     1     1    38.0     1   2.0   3.0   650.0   1.0        2   46.0
# 11567     1     2    46.0     1   2.0   2.0   180.0   1.0        3   66.0
# 11598     1     1    38.0     1   2.0   1.0    70.0   1.0        3   25.0
#
# [468 rows x 10 columns]

# %% [markdown]
# ### Creamos una nueva variable con el monto mensual de ingresos

# %%
# Diccionario con los multiplicadores de frecuencia
multiplicadores = {
    1: 30,  # Diario
    2: 4,   # Semanal
    3: 2,   # Quincenal
    4: 1    # Mensual
}

# Calcular el ingreso mensual usando el diccionario
venezolanos['ingreso_mensual'] = venezolanos['p622_1'] * venezolanos['p621'].map(multiplicadores)
# Creamos una nueva columna para el logaritmo del ingreso mensual
venezolanos['log_ingreso_mensual'] = venezolanos['ingreso_mensual'].apply(lambda x: np.log(x) if x > 0 else np.nan)

# Calcular las horas de trabajo mensual
venezolanos['horas_mensual'] = venezolanos['p616a'] *4
venezolanos
# Out:
#        p203  p204  p205_a  p208  p613  p621  p622_1  p636  estrato  p616a  \
# 14        4     2    17.0     1   2.0   1.0    20.0   1.0        3    8.0
# 45        1     1    52.0     1   2.0   1.0    80.0   1.0        2   50.0
# 65        1     2    36.0     1   2.0   2.0   350.0   1.0        3   66.0
# 82        1     1    48.0     1   2.0   4.0  1000.0   1.0        4   72.0
# 111      11     1    26.0     1   2.0   2.0   280.0   1.0        3   48.0
# ...     ...   ...     ...   ...   ...   ...     ...   ...      ...    ...
# 11530     3     2    23.0     1   2.0   4.0  1800.0   1.0        4   48.0
# 11531     8     1    26.0     1   2.0   2.0   330.0   1.0        4   66.0
# 11545     1     1    38.0     1   2.0   3.0   650.0   1.0        2   46.0
# 11567     1     2    46.0     1   2.0   2.0   180.0   1.0        3   66.0
# 11598     1     1    38.0     1   2.0   1.0    70.0   1.0        3   25.0
#
#        ingreso_mensual  log_ingreso_mensual  horas_mensual
# 14               600.0             6.396930           32.0
# 45              2400.0             7.783224          200.0
# 65              1400.0             7.244228          264.0
# 82              1000.0             6.907755          288.0
# 111             1120.0             7.021084          192.0
# ...                ...                  ...            ...
# 11530           1800.0             7.495542          192.0
# 11531           1320.0             7.185387          264.0
# 11545           1300.0             7.170120          184.0
# 11567            720.0             6.579251          264.0
# 11598           2100.0             7.649693          100.0
#
# [468 rows x 13 columns]

# %%
venezolanos['p208'] = venezolanos['p208'].apply(lambda x: 0 if x == 2 else 1)

venezolanos['p613'] = venezolanos['p613'].apply(lambda x: 0 if x == 2 else 1)

venezolanos['p636'] = venezolanos['p636'].apply(lambda x: 0 if x == 2 else 1)

# %% [markdown]
# ### Renombramos

# %%
venezolanos.rename(columns={
    'p203': 'jefe_hogar',
    'p204': 'sexo',
    'p205_a': 'edad',
    'p208': 'migracion_venezuela',
    'p613': 'firma_contrato',
    'p636': 'trabajo_venezuela',
}, inplace=True)
venezolanos
# Out:
#        jefe_hogar  sexo  edad  migracion_venezuela  firma_contrato  p621  \
# 14              4     2  17.0                    1               0   1.0
# 45              1     1  52.0                    1               0   1.0
# 65              1     2  36.0                    1               0   2.0
# 82              1     1  48.0                    1               0   4.0
# 111            11     1  26.0                    1               0   2.0
# ...           ...   ...   ...                  ...             ...   ...
# 11530           3     2  23.0                    1               0   4.0
# 11531           8     1  26.0                    1               0   2.0
# 11545           1     1  38.0                    1               0   3.0
# 11567           1     2  46.0                    1               0   2.0
# 11598           1     1  38.0                    1               0   1.0
#
#        p622_1  trabajo_venezuela  estrato  p616a  ingreso_mensual  \
# 14       20.0                  1        3    8.0            600.0
# 45       80.0                  1        2   50.0           2400.0
# 65      350.0                  1        3   66.0           1400.0
# 82     1000.0                  1        4   72.0           1000.0
# 111     280.0                  1        3   48.0           1120.0
# ...       ...                ...      ...    ...              ...
# 11530  1800.0                  1        4   48.0           1800.0
# 11531   330.0                  1        4   66.0           1320.0
# 11545   650.0                  1        2   46.0           1300.0
# 11567   180.0                  1        3   66.0            720.0
# 11598    70.0                  1        3   25.0           2100.0
#
#        log_ingreso_mensual  horas_mensual
# 14                6.396930           32.0
# 45                7.783224          200.0
# 65                7.244228          264.0
# 82                6.907755          288.0
# 111               7.021084          192.0
# ...                    ...            ...
# 11530             7.495542          192.0
# 11531             7.185387          264.0
# 11545             7.170120          184.0
# 11567             6.579251          264.0
# 11598             7.649693          100.0
#
# [468 rows x 13 columns]

# %% [markdown]
# ### Nos quedamos con las variables que necesitamos

# %%
venezolanos = venezolanos[['jefe_hogar', 'sexo', 'edad', 'migracion_venezuela', 'firma_contrato', 'trabajo_venezuela', 'estrato', 'ingreso_mensual', 'log_ingreso_mensual', 'horas_mensual']]

# %%
venezolanos
# Out:
#        jefe_hogar  sexo  edad  migracion_venezuela  firma_contrato  \
# 14              4     2  17.0                    1               0
# 45              1     1  52.0                    1               0
# 65              1     2  36.0                    1               0
# 82              1     1  48.0                    1               0
# 111            11     1  26.0                    1               0
# ...           ...   ...   ...                  ...             ...
# 11530           3     2  23.0                    1               0
# 11531           8     1  26.0                    1               0
# 11545           1     1  38.0                    1               0
# 11567           1     2  46.0                    1               0
# 11598           1     1  38.0                    1               0
#
#        trabajo_venezuela  estrato  ingreso_mensual  log_ingreso_mensual  \
# 14                     1        3            600.0             6.396930
# 45                     1        2           2400.0             7.783224
# 65                     1        3           1400.0             7.244228
# 82                     1        4           1000.0             6.907755
# 111                    1        3           1120.0             7.021084
# ...                  ...      ...              ...                  ...
# 11530                  1        4           1800.0             7.495542
# 11531                  1        4           1320.0             7.185387
# 11545                  1        2           1300.0             7.170120
# 11567                  1        3            720.0             6.579251
# 11598                  1        3           2100.0             7.649693
#
#        horas_mensual
# 14              32.0
# 45             200.0
# 65             264.0
# 82             288.0
# 111            192.0
# ...              ...
# 11530          192.0
# 11531          264.0
# 11545          184.0
# 11567          264.0
# 11598          100.0
#
# [468 rows x 10 columns]

# %% [markdown]
# ### Descargamos nuestra data

# %%
venezolanos.to_csv("venezolanos.csv", index=False)

# %% [markdown]
# ## 2. Relación: VD ~ VI

# %% [markdown]
# ### 2.1. Ingreso Mensual - VD

# %%
sns.histplot(venezolanos['log_ingreso_mensual'], kde=True, color="cyan", bins=20)
plt.title("Distribución incondicional del ingreso")
plt.xlabel("Log ingreso mensual")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ### 2.2. Horas Mensual - VI

# %% [markdown]
# #### 2.2.1. Gráfico sobre la relación entre horas de trabajo y logaritmo del ingreso mensual

# %%
plt.scatter(venezolanos['horas_mensual'], venezolanos['log_ingreso_mensual'], alpha=0.7)
plt.title('Relación entre horas de trabajo e ingreso mensual')
plt.xlabel('Horas de trabajo mensual')
plt.ylabel('Log ingreso mensual')
plt.show()

# %% [markdown]
# #### 2.2.2. Regresión lineal simple

# %%
venezolanos = venezolanos.dropna(subset=['horas_mensual', 'log_ingreso_mensual'])

# %%
X = sm.add_constant(venezolanos['horas_mensual'])  # Agregar una constante para el intercepto
y = venezolanos['log_ingreso_mensual']
model2 = sm.OLS(y, X).fit()
y_pred = model2.predict(X)
print(model2.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     log_ingreso_mensual   R-squared:                       0.010
# Model:                             OLS   Adj. R-squared:                  0.008
# Method:                  Least Squares   F-statistic:                     4.892
# Date:                 Fri, 31 Jan 2025   Prob (F-statistic):             0.0275
# Time:                         22:51:07   Log-Likelihood:                -378.10
# No. Observations:                  467   AIC:                             760.2
# Df Residuals:                      465   BIC:                             768.5
# Df Model:                            1
# Covariance Type:             nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             6.8330      0.076     90.298      0.000       6.684       6.982
# horas_mensual     0.0007      0.000      2.212      0.027    8.33e-05       0.001
# ==============================================================================
# Omnibus:                       42.808   Durbin-Watson:                   1.731
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              223.141
# Skew:                           0.053   Prob(JB):                     3.51e-49
# Kurtosis:                       6.385   Cond. No.                         673.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### 2.2.3. Interpretación

# %% [markdown]
# Por cada hora de aumento en la cantidad de horas trabajadas al mes, el logaritmo de ingreso mensual aumenta en 0.07%. Asimismo, la variable es significativa, pues tiene un p-value menor a 0.05. Y la variación del log ingreso mensual se puede explicar al 1%.

# %% [markdown]
# #### 2.2.4. Prueba White

# %%
residuos = model2.resid

# Prueba de White
white_test = het_white(residuos, X)
print("\nPrueba de White:")
print(f"Estadístico LM: {white_test[0]:.4f}")
print(f"p-value LM: {white_test[1]:.4f}")
# Out:
# Prueba de White:
# Estadístico LM: 7.1777
# p-value LM: 0.0276

# %% [markdown]
# El p-value de la Prueba de White es 0.0276 (mucho menor que 0.05), lo que significa que hay evidencia suficiente para rechazar la hipótesis nula de homocedasticidad. Los residuos presentan heterocedasticidad

# %% [markdown]
# #### 2.2.5. Línea de regresión

# %%
plt.scatter(venezolanos['horas_mensual'], venezolanos['log_ingreso_mensual'], alpha=0.7)
plt.plot(venezolanos['horas_mensual'], y_pred, color='red', label='Línea de regresión')
plt.title('Línea de regresión ajustada')
plt.xlabel('Horas de trabajo mensual')
plt.ylabel('Log ingreso mensual')
plt.legend()
plt.show()

# %% [markdown]
# ### 2.3. Trabajó en Venezuela - VI

# %% [markdown]
# #### 2.3.1. Gráfico sobre la relación entre si trabajó previamente en Venezuela y logaritmo del ingreso mensual

# %%
plt.scatter(venezolanos['trabajo_venezuela'], venezolanos['log_ingreso_mensual'], alpha=0.7)
plt.title('Relación entre si trabajo previamente en venezuela con el log. ingreso mensual')
plt.xlabel('Trabajó previamente en Venezuela')
plt.ylabel('Log ingreso mensual')
plt.show()

# %% [markdown]
# #### 2.3.2. Regresión Lineal Simple

# %%
X = sm.add_constant(venezolanos['trabajo_venezuela'])  # Agregar una constante para el intercepto
y = venezolanos['log_ingreso_mensual']
model3 = sm.OLS(y, X).fit()
y_pred = model3.predict(X)
print(model3.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     log_ingreso_mensual   R-squared:                       0.019
# Model:                             OLS   Adj. R-squared:                  0.017
# Method:                  Least Squares   F-statistic:                     8.957
# Date:                 Fri, 31 Jan 2025   Prob (F-statistic):            0.00291
# Time:                         22:51:09   Log-Likelihood:                -376.09
# No. Observations:                  467   AIC:                             756.2
# Df Residuals:                      465   BIC:                             764.5
# Df Model:                            1
# Covariance Type:             nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 6.8530      0.052    130.654      0.000       6.750       6.956
# trabajo_venezuela     0.1788      0.060      2.993      0.003       0.061       0.296
# ==============================================================================
# Omnibus:                       40.895   Durbin-Watson:                   1.765
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              204.052
# Skew:                           0.008   Prob(JB):                     4.91e-45
# Kurtosis:                       6.238   Cond. No.                         3.96
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### 2.3.3. Interpretación

# %% [markdown]
# Si la persona trabajo previamente en Venezuela, el logaritmo de sueldo mensual aumenta en 17%. Esto con una significancia al 0.003. Asimismo el modelo logra explicar la variación de la dependiente al 1.9%.

# %% [markdown]
# #### 2.3.4. Prueba White

# %%
residuos = model3.resid

# Prueba de White
white_test = het_white(residuos, X)
print("\nPrueba de White:")
print(f"Estadístico LM: {white_test[0]:.4f}")
print(f"p-value LM: {white_test[1]:.4f}")
# Out:
# Prueba de White:
# Estadístico LM: 0.7453
# p-value LM: 0.3880

# %% [markdown]
# El p-value de la Prueba de White es 0.3880 (mucho mayor que 0.05), lo que significa que no hay evidencia suficiente para rechazar la hipótesis nula de homocedasticidad. Los residuos presentan homocedasticidad, es decir, la varianza de los errores es constante.

# %% [markdown]
# #### 2.3.5. Línea de regresión

# %%
plt.scatter(venezolanos['trabajo_venezuela'], venezolanos['log_ingreso_mensual'], alpha=0.7)
plt.plot(venezolanos['trabajo_venezuela'], y_pred, color='red', label='Línea de regresión')
plt.title('Línea de regresión ajustada')
plt.xlabel('Trabajó previamente en Venezuela')
plt.ylabel('Log ingreso mensual')
plt.legend()
plt.show()

# %% [markdown]
# ### 2.4. Trabajo Formal - VI

# %% [markdown]
# #### 2.4.1. Gráfico sobre la relación entre trabajo formal y logaritmo del ingreso mensual

# %%
plt.scatter(venezolanos['firma_contrato'], venezolanos['log_ingreso_mensual'], alpha=0.7)
plt.title('Relación entre sifirma contrato laboral con el log. ingreso mensual')
plt.xlabel('Firma contrato laboral')
plt.ylabel('Log ingreso mensual')
plt.show()

# %% [markdown]
# #### 2.4.2. Regresión Lineal Simple

# %%
X = sm.add_constant(venezolanos['firma_contrato'])  # Agregar una constante para el intercepto
y = venezolanos['log_ingreso_mensual']
model4 = sm.OLS(y, X).fit()
y_pred = model4.predict(X)
print(model4.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     log_ingreso_mensual   R-squared:                       0.047
# Model:                             OLS   Adj. R-squared:                  0.045
# Method:                  Least Squares   F-statistic:                     22.88
# Date:                 Fri, 31 Jan 2025   Prob (F-statistic):           2.32e-06
# Time:                         22:51:09   Log-Likelihood:                -369.33
# No. Observations:                  467   AIC:                             742.7
# Df Residuals:                      465   BIC:                             751.0
# Df Model:                            1
# Covariance Type:             nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              6.9462      0.026    262.694      0.000       6.894       6.998
# firma_contrato     0.3589      0.075      4.783      0.000       0.211       0.506
# ==============================================================================
# Omnibus:                       41.411   Durbin-Watson:                   1.780
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              197.579
# Skew:                          -0.125   Prob(JB):                     1.25e-43
# Kurtosis:                       6.177   Cond. No.                         3.08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### 2.4.3. Interpretación

# %% [markdown]
# Si la persona firma contrato laboral, el logaritmo del sueldo mensual puede aumentar en 35%. Esto con un p-value menor al 0.05. Asimismo, la firma de contrato explica al 4% la variabilidad de la dependiente.

# %% [markdown]
# #### 2.4.4. Prueba White

# %%
residuos = model4.resid

# Prueba de White
white_test = het_white(residuos, X)
print("\nPrueba de White:")
print(f"Estadístico LM: {white_test[0]:.4f}")
print(f"p-value LM: {white_test[1]:.4f}")
# Out:
# Prueba de White:
# Estadístico LM: 0.8566
# p-value LM: 0.3547

# %% [markdown]
# El p-value de la Prueba de White es 0.3547 (mucho mayor que 0.05), lo que significa que no hay evidencia suficiente para rechazar la hipótesis nula de homocedasticidad. Los residuos presentan homocedasticidad, es decir, la varianza de los errores es constante.

# %% [markdown]
# #### 2.4.5. Línea de regresión

# %%
plt.scatter(venezolanos['firma_contrato'], venezolanos['log_ingreso_mensual'], alpha=0.7)
plt.plot(venezolanos['firma_contrato'], y_pred, color='red', label='Línea de regresión')
plt.title('Línea de regresión ajustada')
plt.xlabel('Firma contrato laboral')
plt.ylabel('Log ingreso mensual')
plt.legend()
plt.show()

# %% [markdown]
# ### 2.5. Edad - VI

# %% [markdown]
# #### 2.5.1. Gráfico sobre la relación entre edad y logaritmo del ingreso mensual

# %%
plt.scatter(venezolanos['edad'], venezolanos['log_ingreso_mensual'], alpha=0.7)
plt.title('Relación entre edad de trabajo e ingreso mensual')
plt.xlabel('Edad en años')
plt.ylabel('Log ingreso mensual')
plt.show()

# %% [markdown]
# #### 2.5.2. Regresión Lineal Simple

# %%
X = sm.add_constant(venezolanos['edad']) 
y = venezolanos['log_ingreso_mensual']
model5 = sm.OLS(y, X).fit()
y_pred = model5.predict(X)
print(model5.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     log_ingreso_mensual   R-squared:                       0.007
# Model:                             OLS   Adj. R-squared:                  0.005
# Method:                  Least Squares   F-statistic:                     3.120
# Date:                 Fri, 31 Jan 2025   Prob (F-statistic):             0.0780
# Time:                         22:51:10   Log-Likelihood:                -378.99
# No. Observations:                  467   AIC:                             762.0
# Df Residuals:                      465   BIC:                             770.3
# Df Model:                            1
# Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.8489      0.084     81.307      0.000       6.683       7.014
# edad           0.0045      0.003      1.766      0.078      -0.001       0.009
# ==============================================================================
# Omnibus:                       42.250   Durbin-Watson:                   1.738
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              218.488
# Skew:                          -0.027   Prob(JB):                     3.60e-48
# Kurtosis:                       6.350   Cond. No.                         111.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### 2.5.3. Interpretación

# %% [markdown]
# Por cada año de aumento en edad, el logaritmo de ingreso mensual aumenta en 0.45%. Sin embargo, la variable no es estadísticamente significativa, pues tiene un p-value mayor a 0.05. Asimismo, puede explicar a un 0.7% la variabilidad de la dependiente.

# %% [markdown]
# #### 2.5.4. Prueba White

# %%
residuos = model5.resid

# Prueba de White
white_test = het_white(residuos, X)
print("\nPrueba de White:")
print(f"Estadístico LM: {white_test[0]:.4f}")
print(f"p-value LM: {white_test[1]:.4f}")
# Out:
# Prueba de White:
# Estadístico LM: 0.3044
# p-value LM: 0.8588

# %% [markdown]
# El p-value de la Prueba de White es 0.8588 (mucho mayor que 0.05), lo que significa que no hay evidencia suficiente para rechazar la hipótesis nula de homocedasticidad. Los residuos presentan homocedasticidad, es decir, la varianza de los errores es constante.

# %% [markdown]
# ## 3. Regresión Múltiple

# %%
y = venezolanos['log_ingreso_mensual']  
X = venezolanos[['horas_mensual', 'trabajo_venezuela', 'firma_contrato', 'edad' ]]  

X = sm.add_constant(X)
model_final = sm.OLS(y, X).fit()

y_pred = model_final.predict(X)

print(model_final.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     log_ingreso_mensual   R-squared:                       0.077
# Model:                             OLS   Adj. R-squared:                  0.069
# Method:                  Least Squares   F-statistic:                     9.647
# Date:                 Fri, 31 Jan 2025   Prob (F-statistic):           1.68e-07
# Time:                         22:51:10   Log-Likelihood:                -361.82
# No. Observations:                  467   AIC:                             733.6
# Df Residuals:                      462   BIC:                             754.4
# Df Model:                            4
# Covariance Type:             nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 6.5862      0.114     57.644      0.000       6.362       6.811
# horas_mensual         0.0008      0.000      2.414      0.016       0.000       0.001
# trabajo_venezuela     0.1537      0.061      2.537      0.012       0.035       0.273
# firma_contrato        0.3541      0.074      4.763      0.000       0.208       0.500
# edad                  0.0023      0.003      0.907      0.365      -0.003       0.007
# ==============================================================================
# Omnibus:                       38.866   Durbin-Watson:                   1.800
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              183.037
# Skew:                           0.003   Prob(JB):                     1.80e-40
# Kurtosis:                       6.067   Cond. No.                     1.06e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.06e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Interpretación

# %% [markdown]
# - **Coeficientes de regresión parcial:**
#
# Variable dependiente: log Y
#
# Por cada hora adicional de trabajo mensual, manteniendo todo lo demás constante, el ingreso mensual promedio aumenta en 0.08%. Es estadísticamente significativo al 5% (p<0.05).
#
# Si la persona ha trabajado previamente en Venezuela, manteniendo todo lo demás constante, el ingreso mensual promedio aumenta en 15.37%. Es estadísticamente significativo al 5% (p<0.05).
#
# Si la persona trabaja bajo contrato (formalmente), manteniendo todo lo demás constante, el ingreso mensual promedio aumento en 35.41%. Es estadísticamente significativo al 1% (p<0.01).
#
# Por cada año adicional de edad, manteniendo todo lo demás constante, el ingreso mensual promedio aumenta en 0.23%. No resulta estadísticamente significativo.
#
# - **Estadístico F**
#
# Con un p-value asociado <0.01 se rechaza la hipótesis nula (H0: todos los coeficientes de las variables explicativas son iguales a cero) con un nivel de confianza alto (99%). El modelo es estadísticamente significativo en su conjunto.
#
#     No implica que todas las variables sean significativas individualmente. Verificar p-value para cada coeficiente.
#
# - **Bondad de ajuste:**
#
# R^2: El R-squared indica que aproximadamente el 7.7% de la variabilidad del log-ingreso mensual es explicada por las variables incluidas en el modelo. Esto es un valor bajo, lo que sugiere que hay muchos factores no incluidos en el modelo que afectan el ingreso mensual.
#
# R^2 ajustado: El R-squared ajustado es ligeramente menor (6.9%) y penaliza la inclusión de variables que no aportan significativamente al ajuste del modelo. Esto refuerza la necesidad de considerar otras variables o transformar las actuales para mejorar la calidad del modelo.
#
# - **Diagnóstico de violaciones de los supuestos**
#
# Autocorrelación:
#
# Estadístico d (Durbin-Watson: 1.800)
#
# Valor cercano a 2, lo que sugiere que no hay fuerte autocorrelación en los residuos.

# %% [markdown]
# ### 3.1. Homocedasticidad

# %%
# Extraer residuos del modelo
residuos = model_final.resid

# Prueba de White
white_test = het_white(residuos, X)
print("\nPrueba de White:")
print(f"Estadístico LM: {white_test[0]:.4f}")
print(f"p-value LM: {white_test[1]:.4f}")
# Out:
# Prueba de White:
# Estadístico LM: 16.7962
# p-value LM: 0.1574

# %% [markdown]
# **Interpretación:** El p-value de la prueba de White es mayor a 0.05, lo que significa no se rechaza la hipótesis nula. Es decir, hay presencia de heterocedasticidad.

# %% [markdown]
# #### 3.2. No Multicolinealidad

# %%
# Multicolinealidad

# Calcular VIF para cada variable explicativa
vif_data = pd.DataFrame()
vif_data["Variable"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Mostrar los resultados
print(vif_data)
# Out:
#             Variable        VIF
# 0              const  21.873541
# 1      horas_mensual   1.015023
# 2  trabajo_venezuela   1.085710
# 3     firma_contrato   1.007385
# 4               edad   1.103107

# %% [markdown]
# **Interpretación:** No hay evidencia de multicolinealidad. Los resultados de VIF están debajo del 5, lo que sugirere que no tienen una correlación problemática entre si.

# %% [markdown]
# ## 4. Conclusión

# %% [markdown]
# El modelo explica un 7.7% de los casos. Esto podría indicar que, si bien las variables tradicionalmente relacionadas al ingreso, como lo son la experiencia laboral (relacionada con la edad y la experiencia previa en Venezuela), la formalidad y la exigencia de horas-hombre, podrían haber otras que sirvan para explicar el ingreso mensual en mayor medida. Por ejemplo, la ubicación geográfica del empleo, habilidades específicas del individuo, género, sector del empleo, entre otras.
